# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import csv

# %%
# !unzip wine-reviews.zip
# Out:
# Archive:  wine-reviews.zip
#   inflating: winemag-data-130k-v2.csv
#   inflating: winemag-data-130k-v2.json
#   inflating: winemag-data_first150k.csv

# %%
df1 = pd.read_csv('winemag-data-130k-v2.csv', encoding="latin1")
df2 = pd.read_csv('winemag-data_first150k.csv', encoding="latin1")

# %%
df1.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                       VulkÃ  Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df2.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La BÃ©gude, named af...
#
#                              designation  points  price        province  \
# 0                      Martha's Vineyard      96  235.0      California
# 1  Carodorum SelecciÃ³n Especial Reserva      96  110.0  Northern Spain
# 2          Special Selected Late Harvest      96   90.0      California
# 3                                Reserve      96   65.0          Oregon
# 4                            La BrÃ»lade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
###LO DE LA PARTE DE ARRIBA ES PORQUE ME CONFUNDI DE AR HIVO IGNORELO JAJAJAJAJAJAJ

# %%
# !unzip avocado-prices.zip
# Out:
# Archive:  avocado-prices.zip
#   inflating: avocado.csv

# %%
aguacatedf = pd.read_csv('avocado.csv', encoding="latin1")

# %%
aguacatedf.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
aguacatedf
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
aguacatedf.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
TAverage = aguacatedf.loc[:, ['AveragePrice']]

# %%
TAverage
# Out:
#        AveragePrice
# 0              1.33
# 1              1.35
# 2              0.93
# 3              1.08
# 4              1.28
# ...             ...
# 18244          1.63
# 18245          1.71
# 18246          1.87
# 18247          1.93
# 18248          1.62
#
# [18249 rows x 1 columns]

# %%
dfaguacate = TAverage.cumsum
dfaguacate
# Out:
# <bound method DataFrame.cumsum of        AveragePrice
# 0              1.33
# 1              1.35
# 2              0.93
# 3              1.08
# 4              1.28
# ...             ...
# 18244          1.63
# 18245          1.71
# 18246          1.87
# 18247          1.93
# 18248          1.62
#
# [18249 rows x 1 columns]>

# %%
TAverage['AveragePrice'].describe()
# Out:
# count    18249.000000
# mean         1.405978
# std          0.402677
# min          0.440000
# 25%          1.100000
# 50%          1.370000
# 75%          1.660000
# max          3.250000
# Name: AveragePrice, dtype: float64

# %%
TAverage['AveragePrice'].max()
# Out:
# 3.25

# %%
#Respuesta a la pregunta número 1

# %%
R1 = "El promedio mas alto es %" + str(TAverage['AveragePrice'].max())
R1
# Out:
# 'El promedio mas alto es %3.25'

# %%
PBags=aguacatedf[["Small Bags", "Large Bags","XLarge Bags"]]
PBags
# Out:
#        Small Bags  Large Bags  XLarge Bags
# 0         8603.62       93.25          0.0
# 1         9408.07       97.49          0.0
# 2         8042.21      103.14          0.0
# 3         5677.40      133.76          0.0
# 4         5986.26      197.69          0.0
# ...           ...         ...          ...
# 18244    13066.82      431.85          0.0
# 18245     8940.04      324.80          0.0
# 18246     9351.80       42.31          0.0
# 18247    10919.54       50.00          0.0
# 18248    11988.14       26.01          0.0
#
# [18249 rows x 3 columns]

# %%
PAgucates = aguacatedf[["Small Bags", "Large Bags","XLarge Bags","type"]]
PAgucates
# Out:
#        Small Bags  Large Bags  XLarge Bags          type
# 0         8603.62       93.25          0.0  conventional
# 1         9408.07       97.49          0.0  conventional
# 2         8042.21      103.14          0.0  conventional
# 3         5677.40      133.76          0.0  conventional
# 4         5986.26      197.69          0.0  conventional
# ...           ...         ...          ...           ...
# 18244    13066.82      431.85          0.0       organic
# 18245     8940.04      324.80          0.0       organic
# 18246     9351.80       42.31          0.0       organic
# 18247    10919.54       50.00          0.0       organic
# 18248    11988.14       26.01          0.0       organic
#
# [18249 rows x 4 columns]

# %%
##Gráfica
###Respuesta a la pregunta número 2
#En la bolsas más vendidas son las pequeñas, hay mayor venta en ellas.
#se manejan más los aguacates organicos que los convencionales, me percate de esto por la tabla.

# %%
sns.pairplot(PBags, kind="reg")
plt.show()

# %%
sns.pairplot(PAgucates)
plt.show()

# %%
PAgucates.dtypes
# Out:
# Small Bags     float64
# Large Bags     float64
# XLarge Bags    float64
# type            object
# dtype: object

# %%
aguacatedf
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
aguacatedf.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
aguacatedf.type
# Out:
# 0        conventional
# 1        conventional
# 2        conventional
# 3        conventional
# 4        conventional
#              ...
# 18244         organic
# 18245         organic
# 18246         organic
# 18247         organic
# 18248         organic
# Name: type, Length: 18249, dtype: object

# %%
Ptipy = aguacatedf[["type"]]
Ptipy
# Out:
#                type
# 0      conventional
# 1      conventional
# 2      conventional
# 3      conventional
# 4      conventional
# ...             ...
# 18244       organic
# 18245       organic
# 18246       organic
# 18247       organic
# 18248       organic
#
# [18249 rows x 1 columns]

# %%
TTotalBags['Total Bags'].describe()
# Out:
# count    1.824900e+04
# mean     2.396392e+05
# std      9.862424e+05
# min      0.000000e+00
# 25%      5.088640e+03
# 50%      3.974383e+04
# 75%      1.107834e+05
# max      1.937313e+07
# Name: Total Bags, dtype: float64

# %%
#Respuesta a la pregunta número 3

# %%
R1 = "El promedio de bolsas vendidas %" + str(TTotalBags['Total Bags'].mean())
R1
# Out:
# 'El promedio de bolsas vendidas %239639.20205983886'

# %%
aguacatedf
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
#Respuesta 4 ¿Para que te servio analizar estos datos y que has aprendido de todo esto?
#R4: Para poder hacer limpieza de dato, con esta informacion podemos ayudarnos a mejorar la inversion al tipo de aguacate que
#se podria vender mejor.
#Analisis: He podido y he aprendido a manejar de mejor manera el lenguaje y saber implementarlipieza de datos y analisis
